# %% [markdown]
# <a href="https://colab.research.google.com/github/EmreYY20/Manim-Algo-Viz/blob/main/PageRank_manim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
